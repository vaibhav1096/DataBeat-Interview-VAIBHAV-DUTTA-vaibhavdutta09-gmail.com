# %%
import pandas as pd

# %% [markdown]
# ### Stat2Data Package	 has max no of items
# ### openintro Package	has max no of Rows
# ### Statistics of Deadly Quarrels	has highest n factor

# %%
df = pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv')

# %%
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1714 entries, 0 to 1713
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Package      1714 non-null   object
#  1   Item         1714 non-null   object
#  2   Title        1714 non-null   object
#  3   Rows         1714 non-null   int64
#  4   Cols         1714 non-null   int64
#  5   n_binary     1714 non-null   int64
#  6   n_character  1714 non-null   int64
#  7   n_factor     1714 non-null   int64
#  8   n_logical    1714 non-null   int64
#  9   n_numeric    1714 non-null   int64
#  10  CSV          1714 non-null   object
#  11  Doc          1714 non-null   object
# dtypes: int64(7), object(5)
# memory usage: 160.8+ KB

# %%
pd.Categorical(df['Package'])
# Out:
# [AER, AER, AER, AER, AER, ..., vcd, vcd, vcd, vcd, vcd]
# Length: 1714
# Categories (53, object): [AER, COUNT, DAAG, Ecdat, ..., survival, texmex, tidyr, vcd]

# %%
df[df['n_factor']==max(df['n_factor'])]
# Out:
#       Package      Item                          Title  Rows  Cols  n_binary  \
# 792  HistData  Quarrels  Statistics of Deadly Quarrels   779    84        50
#
#      n_character  n_factor  n_logical  n_numeric  \
# 792            0        64          0         20
#
#                                                    CSV  \
# 792  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                    Doc
# 792  https://vincentarelbundock.github.io/Rdatasets...

# %%
a=df.groupby(by='Package')

# %%
a.count().sort_values(by='Title')
# Out:
#                 Item  Title  Rows  Cols  n_binary  n_character  n_factor  \
# Package
# lmec               1      1     1     1         1            1         1
# ggplot2movies      1      1     1     1         1            1         1
# palmerpenguins     1      1     1     1         1            1         1
# mi                 2      2     2     2         2            2         2
# hwde               2      2     2     2         2            2         2
# multgee            2      2     2     2         2            2         2
# plyr               2      2     2     2         2            2         2
# dragracer          3      3     3     3         3            3         3
# reshape2           3      3     3     3         3            3         3
# HLMdiag            4      4     4     4         4            4         4
# sandwich           4      4     4     4         4            4         4
# forecast           5      5     5     5         5            5         5
# ...

# %%
a.sum().sort_values(by='Rows')
# Out:
#                    Rows  Cols  n_binary  n_character  n_factor  n_logical  \
# Package
# hwde                 45     8         1            1         5          0
# palmerpenguins      344     8         1            0         3          0
# lmec                373     5         0            0         1          0
# mi                  932    14         3            0         0          0
# reshape2            942    21         6            0         8          0
# lattice            1031    26         5            0        11          0
# rpart              1415    65         4            0        21          0
# quantreg           1816    45         7            0         0          2
# sem                1979    68         3            0         6          0
# dragracer          2204    38         9           23         0          0
# multgee            2354    11         3            0         0          0
# ...
