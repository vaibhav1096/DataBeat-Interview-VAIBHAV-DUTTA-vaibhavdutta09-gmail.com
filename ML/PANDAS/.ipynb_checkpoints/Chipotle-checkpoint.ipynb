# %%
import pandas as pd

# %%
df=pd.read_csv(r"D:\LEARNING\INEURON\PYTHON\LIVE CLASSES\PANDAS\chipo.tsv",sep ='\t')

# %% [markdown]
# #### avg quantity per order is 2.5201 and val is 21.394231

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price  value
# 0                                                NaN      2.39    2.39
# 1                                       [Clementine]      3.39    3.39
# 2                                            [Apple]      3.39    3.39
# ...

# %%
df['item_price'].replace("\$", " ", inplace=True, regex=True)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      2.39
# ...

# %%
a=df.groupby(by=['order_id']).aggregate(['count'])
a
# Out:
#          quantity item_name choice_description item_price value
#             count     count              count      count count
# order_id
# 1               4         4                  2          4     4
# 2               1         1                  1          1     1
# 3               2         2                  1          2     2
# 4               2         2                  2          2     2
# 5               2         2                  1          2     2
# ...           ...       ...                ...        ...   ...
# 1830            2         2                  2          2     2
# 1831            3         3                  1          3     3
# 1832            2         2                  1          2     2
# 1833            2         2                  2          2     2
# 1834            3         3                  3          3     3
#
# [1834 rows x 5 columns]

# %%
np.mean(a[('quantity', 'count')])
# Out:
# 2.520174482006543

# %%
df['value'] =pd.to_numeric(df['item_price'])* pd.to_numeric(df['quantity'])

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  value
# 0                                                   NaN      2.39    2.39
# ...

# %%
grouped = df.groupby(['order_id']).sum()

# %%
np.mean(grouped)
# Out:
# quantity     2.711014
# value       21.394231
# dtype: float64
